# %% [markdown]
# # FIFA World Cup Fun Statistics

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
matches = pd.read_csv('WorldCupMatches.csv')
players = pd.read_csv('WorldCupPlayers.csv')

# %%
matches2 = matches.dropna()

# %%
matches2
# Out:
#        Year              Datetime                     Stage  \
# 0    1930.0  13 Jul 1930 - 15:00                    Group 1
# 1    1930.0  13 Jul 1930 - 15:00                    Group 4
# 2    1930.0  14 Jul 1930 - 12:45                    Group 2
# 3    1930.0  14 Jul 1930 - 14:50                    Group 3
# 4    1930.0  15 Jul 1930 - 16:00                    Group 1
# ..      ...                   ...                       ...
# 847  2014.0  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014.0  08 Jul 2014 - 17:00                Semi-finals
# 849  2014.0  09 Jul 2014 - 17:00                Semi-finals
# 850  2014.0  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014.0  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
players
# Out:
#        RoundID    MatchID Team Initials               Coach Name Line-up  \
# 0          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 1          201       1096           MEX         LUQUE Juan (MEX)       S
# 2          201       1096           FRA      CAUDRON Raoul (FRA)       S
# 3          201       1096           MEX         LUQUE Juan (MEX)       S
# 4          201       1096           FRA      CAUDRON Raoul (FRA)       S
# ...        ...        ...           ...                      ...     ...
# 37779   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37780   255959  300186501           GER       LOEW Joachim (GER)       N
# 37781   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
# 37782   255959  300186501           GER       LOEW Joachim (GER)       N
# 37783   255959  300186501           ARG  SABELLA Alejandro (ARG)       N
#
#        Shirt Number       Player Name Position       Event
# ...

# %%
worldcup
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
#convert float to int and fill NA with 0 for the column 'Year'
matches2['Year'] = matches2['Year'].fillna(0).astype(int)
# Out:
# <ipython-input-51-3b30fecec7cf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches2['Year'] = matches2['Year'].fillna(0).astype(int)

# %%
#create a column: total goals 
matches2['Total Goals'] = matches2['Home Team Goals'] + matches2['Away Team Goals']
# Out:
# <ipython-input-52-b6b468cd8dae>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   matches2['Total Goals'] = matches2['Home Team Goals'] + matches2['Away Team Goals']

# %%
matches2
# Out:
#      Year              Datetime                     Stage  \
# 0    1930  13 Jul 1930 - 15:00                    Group 1
# 1    1930  13 Jul 1930 - 15:00                    Group 4
# 2    1930  14 Jul 1930 - 12:45                    Group 2
# 3    1930  14 Jul 1930 - 14:50                    Group 3
# 4    1930  15 Jul 1930 - 16:00                    Group 1
# ..    ...                   ...                       ...
# 847  2014  05 Jul 2014 - 17:00             Quarter-finals
# 848  2014  08 Jul 2014 - 17:00                Semi-finals
# 849  2014  09 Jul 2014 - 17:00                Semi-finals
# 850  2014  12 Jul 2014 - 17:00   Play-off for third place
# 851  2014  13 Jul 2014 - 16:00                      Final
#
#                  Stadium             City Home Team Name  Home Team Goals  \
# 0                Pocitos      Montevideo          France              4.0
# 1         Parque Central      Montevideo             USA              3.0
# ...

# %%
#select only the rows that has appropriate year data
matches3 = matches2[~matches2['Year'].isin([0])]

# %%
f,ax = plt.subplots(figsize=(12,7))
sns.barplot(data=matches3,x='Year',y='Total Goals',color='darkblue')
ax.set_title('Average Goals Scored in World Cup Matches By Year')
ax.set_ylabel('Average Goals')
ax.set_xlabel('Year')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '1930'),
#  Text(1, 0, '1934'),
#  Text(2, 0, '1938'),
#  Text(3, 0, '1950'),
#  Text(4, 0, '1954'),
#  Text(5, 0, '1958'),
#  Text(6, 0, '1962'),
#  Text(7, 0, '1966'),
#  Text(8, 0, '1970'),
#  Text(9, 0, '1974'),
#  Text(10, 0, '1978'),
#  Text(11, 0, '1982'),
#  Text(12, 0, '1986'),
#  Text(13, 0, '1990'),
#  Text(14, 0, '1994'),
#  Text(15, 0, '1998'),
#  Text(16, 0, '2002'),
#  Text(17, 0, '2006'),
#  Text(18, 0, '2010'),
#  Text(19, 0, '2014')]

# %%
#group total goals by year 
worldcup_goals = matches2.groupby('Year')['Total Goals'].sum().reset_index()

# %%
#convert float to int for year column
worldcup_goals['Year'] = worldcup_goals['Year'].astype(int)

# %%
worldcup_goals['Year']
# Out:
# 0     1930
# 1     1934
# 2     1938
# 3     1950
# 4     1954
# 5     1958
# 6     1962
# 7     1966
# 8     1970
# 9     1974
# 10    1978
# 11    1982
# 12    1986
# 13    1990
# 14    1994
# 15    1998
# 16    2002
# 17    2006
# 18    2010
# 19    2014
# Name: Year, dtype: int64

# %%
f,ax = plt.subplots(figsize = (12,7))
sns.set_style('whitegrid')
sns.set_context('poster',font_scale = .8)
sns.barplot(data=worldcup_goals,x='Year',y='Total Goals',color = 'darkblue')
ax.set_title('Total Goals Scored In World Cup Matches By Year',fontsize = 20)
ax.set_xlabel('Year',fontsize = 20)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 45)
ax.set_ylabel('Total Goals')
plt.show()

# %%
host = pd.read_csv('WorldCups.csv')

# %%
host
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
#convert float to int and fill NA with 0 for the column 'Year'
worldcup['Year'] = worldcup['Year'].fillna(0).astype(int)

# %%
worldcup
# Out:
#     Year       Country      Winner      Runners-Up        Third  \
# 0   1930       Uruguay     Uruguay       Argentina          USA
# 1   1934         Italy       Italy  Czechoslovakia      Germany
# 2   1938        France       Italy         Hungary       Brazil
# 3   1950        Brazil     Uruguay          Brazil       Sweden
# 4   1954   Switzerland  Germany FR         Hungary      Austria
# 5   1958        Sweden      Brazil          Sweden       France
# 6   1962         Chile      Brazil  Czechoslovakia        Chile
# 7   1966       England     England      Germany FR     Portugal
# 8   1970        Mexico      Brazil           Italy   Germany FR
# 9   1974       Germany  Germany FR     Netherlands       Poland
# 10  1978     Argentina   Argentina     Netherlands       Brazil
# 11  1982         Spain       Italy      Germany FR       Poland
# 12  1986        Mexico   Argentina      Germany FR       France
# 13  1990         Italy  Germany FR       Argentina        Italy
# ...

# %%
#select only the rows that has appropriate year data
worldcup2 = worldcup[~worldcup['Year'].isin([0])]

# %%
#boxplot home team goals by year
f,ax2 = plt.subplots(figsize=(12,7))
sns.set_context('notebook')
sns.set_style('whitegrid')
sns.boxplot(data=worldcup2,x='Year',y='Home Team Goals',palette = 'Spectral')
ax2.set_title('Home Team Goals Scored in World Cup Matches By Year',fontsize = 25)
ax2.set_xticklabels(ax.get_xticklabels(),rotation = 45)
# Out:
# [Text(0, 0, '1930'),
#  Text(1, 0, '1934'),
#  Text(2, 0, '1938'),
#  Text(3, 0, '1950'),
#  Text(4, 0, '1954'),
#  Text(5, 0, '1958'),
#  Text(6, 0, '1962'),
#  Text(7, 0, '1966'),
#  Text(8, 0, '1970'),
#  Text(9, 0, '1974'),
#  Text(10, 0, '1978'),
#  Text(11, 0, '1982'),
#  Text(12, 0, '1986'),
#  Text(13, 0, '1990'),
#  Text(14, 0, '1994'),
#  Text(15, 0, '1998'),
#  Text(16, 0, '2002'),
#  Text(17, 0, '2006'),
#  Text(18, 0, '2010'),
#  Text(19, 0, '2014')]
